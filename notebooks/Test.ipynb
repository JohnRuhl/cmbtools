# %% [markdown]
# Here is a plot of what we're talking about!  <b> (x cubed!) </b> <BR>
# All good now. hi henry!

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(-5,5,0.1)
plt.plot(x,x**4-x**3)
plt.grid()

# %%
plt.plot(x,np.sin(x))

# %%
.67**3
# Out:
# 0.30076300000000006

# %%
sigma=6e-8
sigma*20**4
# Out:
# 0.0096

# %%
2.5**2/100.
# Out:
# 0.0625

# %%
2.5/100.
# Out:
# 0.025

# %%
0.025**2*10.
# Out:
# 0.006250000000000001

# %%
3e-5*(13**3 - 4.**3)
# Out:
# 0.06399

# %%
3e-5*(70**3 - 4.**3)
# Out:
# 10.28808

# %%
50**2/100.
# Out:
# 25.0
